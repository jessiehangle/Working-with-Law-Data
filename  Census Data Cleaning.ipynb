# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_rows = 999

# %%
children = pd.read_csv('C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Children_All_PA_Census_ACSST5Y2018.S0101_data_with_overlays_2020-06-23T182909.csv', header=1, low_memory=False)

# %%
children.head()
# Out:
#                      id                             Geographic Area Name  \
# 0  1400000US42001030101  Census Tract 301.01, Adams County, Pennsylvania
# 1  1400000US42001030102  Census Tract 301.02, Adams County, Pennsylvania
# 2  1400000US42001030200     Census Tract 302, Adams County, Pennsylvania
# 3  1400000US42001030300     Census Tract 303, Adams County, Pennsylvania
# 4  1400000US42001030400     Census Tract 304, Adams County, Pennsylvania
#
#    Estimate!!Total!!Total population  \
# 0                               2590
# 1                               5806
# 2                               5430
# 3                               4356
# 4                               5810
#
#    Margin of Error!!Total MOE!!Total population  \
# 0                                            23
# 1                                            17
# 2                                           237
# 3                                           171
# 4                                           199
#
# ...

# %%
children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 458 entries, id to Margin of Error!!Percent Female MOE!!PERCENT ALLOCATED!!Age
# dtypes: int64(186), object(272)
# memory usage: 11.2+ MB

# %%
children.columns = children.columns.str.replace(' ', '')

# %%
children = children.rename(columns={"GeographicAreaName": "name"})

# %%
children.columns = children.columns.str.replace('!!', '_')

# %%
poverty = pd.read_csv('C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Poverty_All_PA_Census_ACSST5Y2018.S1701_data_with_overlays_2020-06-23T181445.csv', header = 1, low_memory=False)

# %%
poverty.head()
# Out:
#                      id                             Geographic Area Name  \
# 0  1400000US42001030101  Census Tract 301.01, Adams County, Pennsylvania
# 1  1400000US42001030102  Census Tract 301.02, Adams County, Pennsylvania
# 2  1400000US42001030200     Census Tract 302, Adams County, Pennsylvania
# 3  1400000US42001030300     Census Tract 303, Adams County, Pennsylvania
# 4  1400000US42001030400     Census Tract 304, Adams County, Pennsylvania
#
#    Estimate!!Total!!Population for whom poverty status is determined  \
# 0                                               2590
# 1                                               5779
# 2                                               5414
# 3                                               4340
# 4                                               5709
#
#    Margin of Error!!Total MOE!!Population for whom poverty status is determined  \
# 0                                                 23
# ...

# %%
poverty.columns = poverty.columns.str.replace(' ', '')
poverty.columns = poverty.columns.str.replace('!!', '_')
poverty.head()
# Out:
#                      id                               GeographicAreaName  \
# 0  1400000US42001030101  Census Tract 301.01, Adams County, Pennsylvania
# 1  1400000US42001030102  Census Tract 301.02, Adams County, Pennsylvania
# 2  1400000US42001030200     Census Tract 302, Adams County, Pennsylvania
# 3  1400000US42001030300     Census Tract 303, Adams County, Pennsylvania
# 4  1400000US42001030400     Census Tract 304, Adams County, Pennsylvania
#
#    Estimate_Total_Populationforwhompovertystatusisdetermined  \
# 0                                               2590
# 1                                               5779
# 2                                               5414
# 3                                               4340
# 4                                               5709
#
#    MarginofError_TotalMOE_Populationforwhompovertystatusisdetermined  \
# 0                                                 23
# 1                                                 39
# ...

# %%
poverty = poverty.rename(columns={"GeographicAreaName": "name"})

# %%
unemployment = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Unemployment_All_PA_Census.csv", header =1, low_memory=False)

# %%
unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 282 entries, id to Margin of Error!!Unemployment rate MOE!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Bachelor's degree or higher
# dtypes: int64(70), object(212)
# memory usage: 6.9+ MB

# %%
unemployment.columns = unemployment.columns.str.replace(' ', '')
unemployment.columns = unemployment.columns.str.replace('!!', '_')
unemployment = unemployment.rename(columns={"GeographicAreaName": "name"})

# %%
education = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Education_All_PA_Census_ACSST5Y2018.S1501_data_with_overlays_2020-06-23T214452.csv", header = 1, low_memory=False)

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 770 entries, id to Estimate!!Percent!!Population 25 years and over!!Population 35 to 44 years!!High school graduate or higher
# dtypes: int64(316), object(454)
# memory usage: 18.9+ MB

# %%
education.columns = education.columns.str.replace(' ', '')
education.columns = education.columns.str.replace('!!', '_')
education = education.rename(columns={"GeographicAreaName": "name"})

# %%
foreign_born = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Foreign_Born_All_PA_Census_ACSDP5Y2018.DP02_data_with_overlays_2020-06-23T184125.csv", header = 1, low_memory=False)

# %%
foreign_born.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 610 entries, id to Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription
# dtypes: int64(314), object(296)
# memory usage: 15.0+ MB

# %%
foreign_born.columns = foreign_born.columns.str.replace(' ', '')
foreign_born.columns = foreign_born.columns.str.replace('!!', '_')
foreign_born= foreign_born.rename(columns={"GeographicAreaName": "name"})

# %%
income = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Incom_All_PA_Census_ACSST5Y2018.S1901_data_with_overlays_2020-06-23T183534.csv", header = 1, low_memory=False)

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 130 entries, id to Margin of Error!!Nonfamily households MOE!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months
# dtypes: int64(8), object(122)
# memory usage: 3.2+ MB

# %%
income.columns = income.columns.str.replace(' ', '')
income.columns = income.columns.str.replace('!!', '_')
income = income.rename(columns={"GeographicAreaName": "name"})

# %%
race = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Race_Ethinicity_All_PA_Census_ACSDP5Y2018.DP05_data_with_overlays_2020-06-23T183327.csv", header = 1, low_memory=False)

# %%
race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 358 entries, id to Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Female
# dtypes: int64(177), object(181)
# memory usage: 8.8+ MB

# %%
race.columns = race.columns.str.replace(' ', '')
race.columns = race.columns.str.replace('!!', '_')
race = race.rename(columns={"GeographicAreaName": "name"})

# %%
snap = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\SNAP_All_PA_Census_ACSST5Y2018.S2201_data_with_overlays_2020-06-23T215301.csv", header = 1, low_memory=False)

# %%
snap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 458 entries, id to Margin of Error!!Households not receiving food stamps/SNAP MOE!!Households!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level
# dtypes: int64(222), object(236)
# memory usage: 11.2+ MB

# %%
snap.columns = snap.columns.str.replace(' ', '')
snap.columns = snap.columns.str.replace('!!', '_')
snap = snap.rename(columns={"GeographicAreaName": "name"})

# %%
non_english = pd.read_csv(r"C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Non_English_Speaker_ACSST5Y2018.S1601_data_with_overlays_2020-07-05T202357.csv", header = 1, low_memory=False)

# %%
non_english.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Columns: 290 entries, id to Margin of Error!!Percent of specified language speakers!!Percent speak English less than very well" MOE!!Population 5 years and over!!All citizens 18 years old and over!!Speak a language other than English!!Other languages"
# dtypes: int64(136), object(154)
# memory usage: 7.1+ MB

# %%
non_english.columns = non_english.columns.str.replace(' ', '')
non_english.columns = non_english.columns.str.replace('!!', '_')
non_english = non_english.rename(columns={"GeographicAreaName": "name"})

# %%
public = pd.read_csv('C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\Public_assistance_data_with_overlays_2020-07-08T203159.csv', header=1, low_memory=False)

# %%
households = pd.read_csv(r'C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\total_household_ACSDT5Y2018.B11002_data_with_overlays_2020-07-11T130623.csv', header=1, low_memory=False)

# %%
population = pd.read_csv(r'C:\\Users\\hangl\\Documents\\Summer RA\\Census Data\total_population_ACSDT5Y2018.B01003_data_with_overlays_2020-07-11T131057.csv', header=1, low_memory=False)

# %%
snap.duplicated(subset=None , keep='first').sum()
# Out:
# 0

# %%
race.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
income.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
foreign_born.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
education.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
unemployment.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
poverty.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
children.duplicated(subset= None, keep='first').sum()
# Out:
# 0

# %%
race.isna().sum()
# Out:
# id                                                                                                                                                    0
# GeographicAreaName                                                                                                                                    0
# PercentMarginofError_SEXANDAGE_Totalpopulation_65yearsandover_Female                                                                                  0
# Estimate_SEXANDAGE_Totalpopulation_65yearsandover_Sexratio(malesper100females)                                                                        0
# MarginofError_SEXANDAGE_Totalpopulation_65yearsandover_Sexratio(malesper100females)                                                                   0
# PercentEstimate_SEXANDAGE_Totalpopulation_65yearsandover_Sexratio(malesper100females)                                                                 0
# ...

# %%
poverty
unemployment
education
foreign_born
income
race 
snap

# %%
df = children[['id', 'name']]

# %%
df = pd.merge(left=df, right=poverty[['id','Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=income[['id','Estimate_Households_Medianincome(dollars)']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=snap[['id','Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=children[['id','Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years']], how='left', left_on='id', right_on='id')

# %%
df.head()
# Out:
#                      id                                             name  \
# 0  1400000US42001030101  Census Tract 301.01, Adams County, Pennsylvania
# 1  1400000US42001030102  Census Tract 301.02, Adams County, Pennsylvania
# 2  1400000US42001030200     Census Tract 302, Adams County, Pennsylvania
# 3  1400000US42001030300     Census Tract 303, Adams County, Pennsylvania
# 4  1400000US42001030400     Census Tract 304, Adams County, Pennsylvania
#
#   Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined  \
# 0                                                  8
# 1                                                4.9
# 2                                               15.9
# 3                                                  7
# 4                                                9.5
#
#   Estimate_Households_Medianincome(dollars)  \
# 0                                     74597
# 1                                     78021
# ...

# %%
df = pd.merge(left=df, right=race[['id','PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=race[['id','PercentEstimate_RACE_Totalpopulation_Onerace_White']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=race[['id','PercentEstimate_RACE_Totalpopulation_Onerace_Asian']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=race[['id','PercentEstimate_HISPANICORLATINOANDRACE_Totalpopulation_HispanicorLatino(ofanyrace)']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=foreign_born[['id','PercentEstimate_PLACEOFBIRTH_Totalpopulation_Foreignborn']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=non_english[['id','Estimate_Percent_Population5yearsandover_SpeakalanguageotherthanEnglish']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=unemployment[['id','Estimate_Unemploymentrate_Population16yearsandover']], how='left', left_on='id', right_on='id')

# %%
df = pd.merge(left=df, right=education[['id','Estimate_Percent_Population25yearsandover_Highschoolgraduateorhigher']], how='left', left_on='id', right_on='id')

# %%
new = df['name'].str.rsplit(",", expand=True)

# %%
new[1].value_counts()
# Out:
#  Allegheny County         402
#  Philadelphia County      384
#  Montgomery County        211
#  Delaware County          144
#  Bucks County             143
#  Chester County           116
#  Luzerne County           104
#  Westmoreland County      100
#  Lancaster County          98
#  Berks County              90
#  York County               90
#  Lehigh County             76
#  Erie County               72
#  Northampton County        68
#  Dauphin County            65
#  Washington County         59
#  Lackawanna County         59
#  Beaver County             51
#  Cumberland County         49
#  Butler County             44
#  Cambria County            42
#  Schuylkill County         40
#  Fayette County            36
#  Blair County              34
#  Monroe County             33
#  Lebanon County            31
#  Centre County             31
#  Mercer County             30
#  Lycoming County           29
#  Lawrence County           28
#  Franklin County           27
# ...

# %%
df["County"]= new[1]

# %%
df.shape
# Out:
# (3218, 14)

# %%
buck = df[df['County'].str.contains("Bucks")]
buck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143 entries, 644 to 786
# Data columns (total 15 columns):
# id                                                                                     143 non-null object
# name                                                                                   143 non-null object
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           143 non-null object
# Estimate_Households_Medianincome(dollars)                                              143 non-null object
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          143 non-null object
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    143 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    143 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     143 non-null object
# ...

# %%
chester = df[df['County'].str.contains("Chester")]
chester.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116 entries, 918 to 1033
# Data columns (total 15 columns):
# id                                                                                     116 non-null object
# name                                                                                   116 non-null object
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           116 non-null object
# Estimate_Households_Medianincome(dollars)                                              116 non-null object
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          116 non-null object
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    116 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    116 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     116 non-null object
# ...

# %%
delaware = df[df['County'].str.contains("Delaware")]
delaware.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 1225 to 1368
# Data columns (total 15 columns):
# id                                                                                     144 non-null object
# name                                                                                   144 non-null object
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           144 non-null object
# Estimate_Households_Medianincome(dollars)                                              144 non-null object
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          144 non-null object
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    144 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    144 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     144 non-null object
# ...

# %%
montgomery = df[df['County'].str.contains("Montgomery")]
montgomery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211 entries, 2093 to 2303
# Data columns (total 15 columns):
# id                                                                                     211 non-null object
# name                                                                                   211 non-null object
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           211 non-null object
# Estimate_Households_Medianincome(dollars)                                              211 non-null object
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          211 non-null object
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    211 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    211 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     211 non-null object
# ...

# %%
philadelphia = df[df['County'].str.contains("Philadelphia")]
philadelphia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384 entries, 2410 to 2793
# Data columns (total 15 columns):
# id                                                                                     384 non-null object
# name                                                                                   384 non-null object
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           384 non-null object
# Estimate_Households_Medianincome(dollars)                                              384 non-null object
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          384 non-null object
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    384 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    384 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     384 non-null object
# ...

# %%
# Append data
final_df = buck.append([chester, delaware, montgomery, philadelphia])
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 998 entries, 644 to 2793
# Data columns (total 15 columns):
# id                                                                                     998 non-null object
# name                                                                                   998 non-null object
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           998 non-null object
# Estimate_Households_Medianincome(dollars)                                              998 non-null object
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          998 non-null object
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    998 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    998 non-null object
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     998 non-null object
# ...

# %%
final_df.head()
# Out:
#                        id                                              name  \
# 644  1400000US42017100102  Census Tract 1001.02, Bucks County, Pennsylvania
# 645  1400000US42017100103  Census Tract 1001.03, Bucks County, Pennsylvania
# 646  1400000US42017100104  Census Tract 1001.04, Bucks County, Pennsylvania
# 647  1400000US42017100105  Census Tract 1001.05, Bucks County, Pennsylvania
# 648  1400000US42017100201  Census Tract 1002.01, Bucks County, Pennsylvania
#
#     Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined  \
# 644                                               10.2
# 645                                               12.7
# 646                                               21.0
# 647                                               11.5
# 648                                                7.2
#
#     Estimate_Households_Medianincome(dollars)  \
# 644                                     64085
# 645                                     57500
# ...

# %%
#merge with public data set
final_df = pd.merge(left=final_df, right=public[['id','Estimate!!Total','Estimate!!Total!!With cash public assistance or Food Stamps/SNAP']], how='left', left_on='GEO_ID', right_on='id')

# %%
final_df['Percent of households with cash public assistance or food stamps/SNAP'] = (final_df['Estimate!!Total!!With cash public assistance or Food Stamps/SNAP']/final_df['Estimate!!Total'])*100

# %%
final_df = final_df.drop(columns=['id','Estimate!!Total','Estimate!!Total!!With cash public assistance or Food Stamps/SNAP'])

# %%
#merge with household data
final_df = pd.merge(left=final_df, right=households[['id','Estimate!!Total']], how='left', left_on='GEO_ID', right_on='id')

# %%
final_df = final_df.drop(columns=['id'])
final_df = final_df.rename(columns={'Estimate!!Total':'Total Number of Households'})

# %%
#Merge with population data
final_df = pd.merge(left=final_df, right=population[['id','Estimate!!Total']], how='left', left_on='GEO_ID', right_on='id')
final_df = final_df.drop(columns=['id'])
final_df = final_df.rename(columns={'Estimate!!Total':'Total Number of People'})

# %%
cols = ['Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined',
       'Estimate_Households_Medianincome(dollars)',
       'Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households',
       'Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years',
       'PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican',
       'PercentEstimate_RACE_Totalpopulation_Onerace_White',
       'PercentEstimate_RACE_Totalpopulation_Onerace_Asian',
       'PercentEstimate_HISPANICORLATINOANDRACE_Totalpopulation_HispanicorLatino(ofanyrace)',
       'PercentEstimate_PLACEOFBIRTH_Totalpopulation_Foreignborn',
       'Estimate_Percent_Population5yearsandover_SpeakalanguageotherthanEnglish',
       'Estimate_Unemploymentrate_Population16yearsandover',
       'Estimate_Percent_Population25yearsandover_Highschoolgraduateorhigher']
final_df[cols] = final_df[cols].replace({'-':np.nan})

# %%
final_df.isna().sum()
# Out:
# id                                                                                      0
# name                                                                                    0
# Estimate_Percentbelowpovertylevel_Populationforwhompovertystatusisdetermined           10
# Estimate_Households_Medianincome(dollars)                                              14
# Estimate_Percenthouseholdsreceivingfoodstamps/SNAP_Households                          12
# Estimate_Percent_Totalpopulation_SELECTEDAGECATEGORIES_Under18years                    10
# PercentEstimate_RACE_Totalpopulation_Onerace_BlackorAfricanAmerican                    10
# PercentEstimate_RACE_Totalpopulation_Onerace_White                                     10
# PercentEstimate_RACE_Totalpopulation_Onerace_Asian                                     10
# PercentEstimate_HISPANICORLATINOANDRACE_Totalpopulation_HispanicorLatino(ofanyrace)    10
# ...

# %%
cols = children.columns
children[cols] = children[cols].replace({'-':np.nan})

# %%
children.isna().sum()
# Out:
# id                                                                                                0
# name                                                                                              0
# Estimate_Total_Totalpopulation                                                                    0
# MarginofError_TotalMOE_Totalpopulation                                                            0
# Estimate_Percent_Totalpopulation                                                                  0
# MarginofError_PercentMOE_Totalpopulation                                                          0
# Estimate_Male_Totalpopulation                                                                     0
# MarginofError_MaleMOE_Totalpopulation                                                             0
# Estimate_PercentMale_Totalpopulation                                                              0
# ...

# %%
children.isnull().any(axis = 1).sum()
# Out:
# 35

# %%
cols = poverty.columns
poverty[cols] = poverty[cols].replace({'-':np.nan})  
poverty.isnull().any(axis = 1).sum()
# Out:
# 3215

# %%
poverty.isna().sum()
# Out:
# id                                                                                                                                                                                0
# name                                                                                                                                                                              0
# Estimate_Total_Populationforwhompovertystatusisdetermined                                                                                                                         0
# MarginofError_TotalMOE_Populationforwhompovertystatusisdetermined                                                                                                                 0
# Estimate_Belowpovertylevel_Populationforwhompovertystatusisdetermined                                                                                                             0
# ...

# %%
cols = income.columns
income[cols] = income[cols].replace({'-':np.nan})  
income.isnull().any(axis = 1).sum()
# Out:
# 133

# %%
cols = snap.columns
snap[cols] = snap[cols].replace({'-':np.nan})  
snap.isnull().any(axis = 1).sum()
# Out:
# 895

# %%
cols = foreign_born.columns
foreign_born[cols] = foreign_born[cols].replace({'-':np.nan})  
foreign_born.isnull().any(axis = 1).sum()
# Out:
# 1256

# %%
cols = education.columns
education[cols] = education[cols].replace({'-':np.nan})  
education.isnull().any(axis = 1).sum()
# Out:
# 3218

# %%
cols = race.columns
race[cols] = race[cols].replace({'-':np.nan})  
race.isnull().any(axis = 1).sum()
# Out:
# 42

# %%
cols = unemployment.columns
unemployment[cols] = unemployment[cols].replace({'-':np.nan})  
unemployment.isnull().any(axis = 1).sum()
# Out:
# 3208

# %%
cols = non_english.columns
non_english[cols] = non_english[cols].replace({'-':np.nan})  
non_english.isnull().any(axis = 1).sum()
# Out:
# 3204

# %%
# Export to csv file
final_df.to_csv('Census Data.csv', index= False)
